# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img= cv.imread("test image.png")

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %%
cv.imshow('test_window',img_rgb)
cv.waitKey(0)
cv.destroyAllWindows()
